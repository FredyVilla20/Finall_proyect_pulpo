# %%
import pandas as pd
import numpy as np

# %%
pulpo_df= pd.read_csv('Base proyecto - ASIGS.csv',low_memory=False)

# %%
pulpo_df.head(20)
# Out:
#    Rango deuda                                 Perf Unnamed: 2  \
# 0        FALSE        juan.asaro@resuelvetudeuda.es  3/03/2022
# 1        FALSE    sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 2        FALSE    sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 3        FALSE    sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 4        FALSE    sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 5        FALSE    sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 6        FALSE   andres.delvalle@resuelvetudeuda.es  3/03/2022
# 7        FALSE   andres.delvalle@resuelvetudeuda.es  3/03/2022
# 8        FALSE   andres.delvalle@resuelvetudeuda.es  3/03/2022
# 9        FALSE   andres.delvalle@resuelvetudeuda.es  3/03/2022
# 10       FALSE   andres.delvalle@resuelvetudeuda.es  3/03/2022
# 11       FALSE   andres.delvalle@resuelvetudeuda.es  3/03/2022
# 12       FALSE    beatriz.moreno@resuelvetudeuda.es  3/03/2022
# 13       FALSE    beatriz.moreno@resuelvetudeuda.es  3/03/2022
# ...

# %%
pulpo_df.tail(20)
# Out:
#       Rango deuda                                  Perf  Unnamed: 2  \
# 50562       4-20k         juan.asaro@resuelvetudeuda.es  30/06/2023
# 50563       4-20k        julio.acuna@resuelvetudeuda.es  30/06/2023
# 50564       4-20k        irene.munoz@resuelvetudeuda.es  30/06/2023
# 50565       4-20k      angela.ospina@resuelvetudeuda.es  30/06/2023
# 50566      20-45k        irene.munoz@resuelvetudeuda.es  30/06/2023
# 50567       4-20k  patricia.cardenas@resuelvetudeuda.es  30/06/2023
# 50568       4-20k   marielena.castro@resuelvetudeuda.es  30/06/2023
# 50569       4-20k     melisa.ferrara@resuelvetudeuda.es  30/06/2023
# 50570        +45k  patricia.cardenas@resuelvetudeuda.es  30/06/2023
# 50571       4-20k     beatriz.moreno@resuelvetudeuda.es  30/06/2023
# 50572       4-20k         juan.asaro@resuelvetudeuda.es  30/06/2023
# 50573       4-20k      angela.ospina@resuelvetudeuda.es  30/06/2023
# 50574      20-45k   marielena.castro@resuelvetudeuda.es  30/06/2023
# ...

# %%
#pulpo_df['Unnamed: 2'] = pulpo_df['fecha_asig']

pulpo_df = pulpo_df.rename(columns={'Unnamed: 2': 'fecha_asig'})

# %%
pulpo_df.head()
# Out:
#   Rango deuda                               Perf fecha_asig  \
# 0       FALSE      juan.asaro@resuelvetudeuda.es  3/03/2022
# 1       FALSE  sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 2       FALSE  sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 3       FALSE  sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 4       FALSE  sandra.sanchez@resuelvetudeuda.es  3/03/2022
#
#                                                 LINK  \
# 0  https://vanex.io/opportunity/78e94e3a-9fa8-4f0...
# 1  https://vanex.io/opportunity/547daa72-3fde-49f...
# 2  https://vanex.io/opportunity/5710bd39-9759-475...
# 3  https://vanex.io/opportunity/746a9728-ff22-443...
# 4  https://vanex.io/opportunity/c6364f81-b759-45f...
#
#                                       ARD   PL    Fecha PL  Monto PL debt_web  \
# 0      javier.martinez@resuelvetudeuda.es  1.0  30/03/2022   4900.00      NaN
# 1  francisco.rodriguez@resuelvetudeuda.es  NaN         NaN       NaN      NaN
# ...

# %%
pulpo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50582 entries, 0 to 50581
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rango deuda   50271 non-null  object
#  1   Perf          50582 non-null  object
#  2   fecha_asig    50581 non-null  object
#  3   LINK          50582 non-null  object
#  4   ARD           50557 non-null  object
#  5   PL            25473 non-null  float64
#  6   Fecha PL      25473 non-null  object
#  7   Monto PL      25473 non-null  object
#  8   debt_web      15518 non-null  object
#  9   ARD_actual    15519 non-null  object
#  10  Calificación  15519 non-null  object
#  11  Names         15519 non-null  object
#  12  Team          0 non-null      float64
#  13  Fecha Co      6443 non-null   object
#  14  Monto Co      6443 non-null   object
# dtypes: float64(2), object(13)
# memory usage: 5.8+ MB

# %%
#Eliminando columnas 
pulpo_df = pulpo_df.drop('Rango deuda',axis=1)
pulpo_df = pulpo_df.drop('debt_web',axis=1)
pulpo_df = pulpo_df.drop('Team',axis=1)
pulpo_df = pulpo_df.drop('Names',axis=1)     
pulpo_df.head()
# Out:
#                                 Perf fecha_asig  \
# 0      juan.asaro@resuelvetudeuda.es  3/03/2022
# 1  sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 2  sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 3  sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 4  sandra.sanchez@resuelvetudeuda.es  3/03/2022
#
#                                                 LINK  \
# 0  https://vanex.io/opportunity/78e94e3a-9fa8-4f0...
# 1  https://vanex.io/opportunity/547daa72-3fde-49f...
# 2  https://vanex.io/opportunity/5710bd39-9759-475...
# 3  https://vanex.io/opportunity/746a9728-ff22-443...
# 4  https://vanex.io/opportunity/c6364f81-b759-45f...
#
#                                       ARD   PL    Fecha PL  Monto PL  \
# 0      javier.martinez@resuelvetudeuda.es  1.0  30/03/2022   4900.00
# 1  francisco.rodriguez@resuelvetudeuda.es  NaN         NaN       NaN
# 2     alberto.guerrero@resuelvetudeuda.es  NaN         NaN       NaN
# 3     victor.blazquezg@resuelvetudeuda.es  NaN         NaN       NaN
# ...

# %%
pulpo_df.shape
# Out:
# (50582, 11)

# %%
pulpo_df['Calificación'].value_counts()
# Out:
# Calificación
# Perfila             4368
# Cerrado Ganado      3843
# En espera           2244
# Propuesta           2116
# Contrato            1556
# Contrato firmado    1187
# No perfila           183
# ICSE                  13
# Baja mismo mes         6
# Sin tocar              3
# Name: count, dtype: int64

# %%
pulpo_df.isnull().sum()
# Out:
# Perf                0
# fecha_asig          1
# LINK                0
# ARD                25
# PL              25109
# Fecha PL        25109
# Monto PL        25109
# ARD_actual      35063
# Calificación    35063
# Fecha Co        44139
# Monto Co        44139
# dtype: int64

# %%
pulpo_df.shape
# Out:
# (50582, 11)

# %%
pulpo_df.head(5)
# Out:
#                                 Perf fecha_asig  \
# 0      juan.asaro@resuelvetudeuda.es  3/03/2022
# 1  sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 2  sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 3  sandra.sanchez@resuelvetudeuda.es  3/03/2022
# 4  sandra.sanchez@resuelvetudeuda.es  3/03/2022
#
#                                                 LINK  \
# 0  https://vanex.io/opportunity/78e94e3a-9fa8-4f0...
# 1  https://vanex.io/opportunity/547daa72-3fde-49f...
# 2  https://vanex.io/opportunity/5710bd39-9759-475...
# 3  https://vanex.io/opportunity/746a9728-ff22-443...
# 4  https://vanex.io/opportunity/c6364f81-b759-45f...
#
#                                       ARD   PL    Fecha PL  Monto PL  \
# 0      javier.martinez@resuelvetudeuda.es  1.0  30/03/2022   4900.00
# 1  francisco.rodriguez@resuelvetudeuda.es  NaN         NaN       NaN
# 2     alberto.guerrero@resuelvetudeuda.es  NaN         NaN       NaN
# 3     victor.blazquezg@resuelvetudeuda.es  NaN         NaN       NaN
# ...

# %%
columna= pulpo_df.columns
columna
# Out:
# Index(['Perf', 'fecha_asig', 'LINK', 'ARD', 'PL', 'Fecha PL', 'Monto PL',
#        'ARD_actual', 'Calificación', 'Fecha Co', 'Monto Co'],
#       dtype='object')

# %%
columnasnuevas = {columna: columna.replace(" ", "_").lower() for columna in columna}
columnasnuevas
# Out:
# {'Perf': 'perf',
#  'fecha_asig': 'fecha_asig',
#  'LINK': 'link',
#  'ARD': 'ard',
#  'PL': 'pl',
#  'Fecha PL': 'fecha_pl',
#  'Monto PL': 'monto_pl',
#  'ARD_actual': 'ard_actual',
#  'Calificación': 'calificación',
#  'Fecha Co': 'fecha_co',
#  'Monto Co': 'monto_co'}

# %%
pulpo_df = pulpo_df.rename(columns = columnasnuevas)
pulpo_df.head(2)
# Out:
#                                 perf fecha_asig  \
# 0      juan.asaro@resuelvetudeuda.es  3/03/2022
# 1  sandra.sanchez@resuelvetudeuda.es  3/03/2022
#
#                                                 link  \
# 0  https://vanex.io/opportunity/78e94e3a-9fa8-4f0...
# 1  https://vanex.io/opportunity/547daa72-3fde-49f...
#
#                                       ard   pl    fecha_pl monto_pl  \
# 0      javier.martinez@resuelvetudeuda.es  1.0  30/03/2022  4900.00
# 1  francisco.rodriguez@resuelvetudeuda.es  NaN         NaN      NaN
#
#   ard_actual calificación fecha_co monto_co
# 0        NaN          NaN      NaN      NaN
# 1        NaN          NaN      NaN      NaN

# %%
pulpo_df['fecha_asig']  = pulpo_df['fecha_asig'] .str.replace('/', '-')
pulpo_df['fecha_asig']
# Out:
# 0         3-03-2022
# 1         3-03-2022
# 2         3-03-2022
# 3         3-03-2022
# 4         3-03-2022
#             ...
# 50577    30-06-2023
# 50578    30-06-2023
# 50579    30-06-2023
# 50580    30-06-2023
# 50581    30-06-2023
# Name: fecha_asig, Length: 50582, dtype: object

# %%
pulpo_df.head(1)
# Out:
#                             perf fecha_asig  \
# 0  juan.asaro@resuelvetudeuda.es  3-03-2022
#
#                                                 link  \
# 0  https://vanex.io/opportunity/78e94e3a-9fa8-4f0...
#
#                                   ard   pl    fecha_pl monto_pl ard_actual  \
# 0  javier.martinez@resuelvetudeuda.es  1.0  30/03/2022  4900.00        NaN
#
#   calificación fecha_co monto_co
# 0          NaN      NaN      NaN

# %%
pulpo_df = pulpo_df.drop(index = 36921)   

pulpo_df.head(1)
# Out:
#                             perf fecha_asig  \
# 0  juan.asaro@resuelvetudeuda.es  3-03-2022
#
#                                                 link  \
# 0  https://vanex.io/opportunity/78e94e3a-9fa8-4f0...
#
#                                   ard   pl    fecha_pl monto_pl ard_actual  \
# 0  javier.martinez@resuelvetudeuda.es  1.0  30/03/2022  4900.00        NaN
#
#   calificación fecha_co monto_co
# 0          NaN      NaN      NaN

# %%
pulpo_df = pulpo_df.drop(index = 50164)

# %%
# cambiando formato de columnas 
pulpo_df['fecha_asig'] = pd.to_datetime(pulpo_df['fecha_asig'], format='%d-%m-%Y')

# %%
pulpo_df['fecha_pl']  = pulpo_df['fecha_pl'] .str.replace('/', '-')
pulpo_df['fecha_pl'] = pd.to_datetime(pulpo_df['fecha_pl'], format='%d-%m-%Y')

# %%
pulpo_df.head(1)
# Out:
#                             perf fecha_asig  \
# 0  juan.asaro@resuelvetudeuda.es 2022-03-03
#
#                                                 link  \
# 0  https://vanex.io/opportunity/78e94e3a-9fa8-4f0...
#
#                                   ard   pl   fecha_pl monto_pl ard_actual  \
# 0  javier.martinez@resuelvetudeuda.es  1.0 2022-03-30  4900.00        NaN
#
#   calificación fecha_co monto_co
# 0          NaN      NaN      NaN

# %%
pulpo_df['pl'] = pulpo_df['pl'].fillna(0).astype(float)
pulpo_df.head(60)
# Out:
#                                       perf fecha_asig  \
# 0            juan.asaro@resuelvetudeuda.es 2022-03-03
# 1        sandra.sanchez@resuelvetudeuda.es 2022-03-03
# 2        sandra.sanchez@resuelvetudeuda.es 2022-03-03
# 3        sandra.sanchez@resuelvetudeuda.es 2022-03-03
# 4        sandra.sanchez@resuelvetudeuda.es 2022-03-03
# 5        sandra.sanchez@resuelvetudeuda.es 2022-03-03
# 6       andres.delvalle@resuelvetudeuda.es 2022-03-03
# 7       andres.delvalle@resuelvetudeuda.es 2022-03-03
# 8       andres.delvalle@resuelvetudeuda.es 2022-03-03
# 9       andres.delvalle@resuelvetudeuda.es 2022-03-03
# 10      andres.delvalle@resuelvetudeuda.es 2022-03-03
# 11      andres.delvalle@resuelvetudeuda.es 2022-03-03
# 12       beatriz.moreno@resuelvetudeuda.es 2022-03-03
# 13       beatriz.moreno@resuelvetudeuda.es 2022-03-03
# 14       beatriz.moreno@resuelvetudeuda.es 2022-03-03
# 15       beatriz.moreno@resuelvetudeuda.es 2022-03-03
# ...

# %%
unique_values = pulpo_df['link'].nunique()
print("Cantidad de valores únicos:", unique_values)
# Out:
# Cantidad de valores únicos: 49149

# %%
pip install webdriver-manager
# Out:
# ...
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver.support import expected_conditions as ec

# %%
PATH=ChromeDriverManager().install()
driver = webdriver.Chrome()

# %%
driver.get('https://vanex.resuelve.io/login')

# %%
driver.get('https://vanex.io/opportunity/fa39e6e7-0699-4678-a004-422ad431b3f4')

# %%
driver.find_element(By.XPATH, "//*[@class='status tag']").text
# Out:
# 'Perfila'

# %%
nombres=[]
calificacion= []
i=0
for e in pulpo_df['link']:
    i+=1
    driver.get(e)
    time.sleep(2)
    n= driver.find_element(By.XPATH, "//*[@class='main-title']").text
    cali= driver.find_element(By.XPATH, "//*[@class='status tag']").text
    nombres.append(n)
    calificacion.append(cali)
    #except:
        #print('este no ha cargado')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[114], line 8
#       6 driver.get(e)
#       7 time.sleep(2)
# ----> 8 n= driver.find_element(By.XPATH, "//*[@class='main-title']").text
#       9 cali= driver.find_element(By.XPATH, "//*[@class='status tag']").text
#      10 nombres.append(n)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:740, in WebDriver.find_element(self, by, value)
#     737     by = By.CSS_SELECTOR
#     738     value = f'[name="{value}"]'
# --> 740 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
# ...

# %%
  '''''try:
    # Wait for the element 
        iteracion = WebDriverWait(driver, 3).until(
        ec.presence_of_element_located((By.XPATH, "//*[@class='main-title']")))
        print(i, end= '\r')v

# %%
len(nombres),len(calificacion)
# Out:
# (1047, 1047)

# %%
print(nombres)
# Out:
# ['Fabio AlvinoReasignable', 'Sergia LugoReasignable', 'María Ángeles Fernández GómezReasignable', 'M.inmaculada Olmedo VazquezReasignable', 'Alejandro Vazquez ÁlvarezReasignable', 'Francisco Jose Borja MaderoReasignable', 'María Luz Tome IglesiasReasignable', 'Pedro Miguel Luengo MoralesReasignable', 'Víctor PerezReasignable', 'Nieves SeijoReasignable', 'Khalid Bourzik .', 'Tomas LeonReasignable', 'Brayan Martin DiazReasignable', 'Edinalda Paixao Dos SantosReasignable', 'Aida Nieto GarciaReasignable', 'Daniel Mendoza SuárezReasignable', 'Maria José Martínez ValverdeReasignable', 'María Carpio Blázquez', 'Jose Yeray Acosta Correa', 'Maria Del Carmen Del Valle Trujillo', 'Pedro Nogal BravoReasignable', 'Maicol Ernesto Emiliano Maicol Ernesto Emiliano Maicol Ernesto EmilianoReasignable', 'Luciano Mendez Gomez', 'Yair Esteban Zuluaga Ramírez', 'Javier Alejandro Garcia Fernandez', 'Juan Ramón Hernández SáezReasignable', 'Carlos De La Fuente SerranoReasignable', 'Mercedes Izquierdo Gonzále
# ...

# %%
print(calificacion)
# Out:
# ['En espera', 'Perfila', 'En espera', 'En espera', 'Contrato', 'Contrato', 'Contrato', 'Contrato', 'En espera', 'Propuesta', 'Cerrado Ganado', 'Perfila', 'En espera', 'En espera', 'Contrato', 'Propuesta', 'En espera', 'Cerrado Ganado', 'Cerrado Ganado', 'Cerrado Ganado', 'Perfila', 'En espera', 'Cerrado Ganado', 'Baja mismo mes', 'Cerrado Ganado', 'En espera', 'Contrato firmado', 'Perfila', 'En espera', 'Contrato', 'Propuesta', 'Contrato firmado', 'Cerrado Ganado', 'En espera', 'No perfila', 'Contrato firmado', 'Cerrado Ganado', 'En espera', 'Perfila', 'En espera', 'En espera', 'En espera', 'Contrato', 'En espera', 'Contrato', 'Contrato', 'Contrato', 'Perfila', 'En espera', 'En espera', 'Contrato', 'Propuesta', 'Perfila', 'Propuesta', 'Cerrado Ganado', 'Contrato', 'En espera', 'Perfila', 'Cerrado Ganado', 'Cerrado Ganado', 'Propuesta', 'Perfila', 'Contrato', 'En espera', 'Perfila', 'Cerrado Ganado', 'Propuesta', 'Cerrado Ganado', 'Contrato firmado', 'Contrato firmado', 'En espera', '
# ...

# %%
enlace=list(pulpo_df['link'])
# Out:
# ['https://vanex.io/opportunity/78e94e3a-9fa8-4f0d-ac43-7ec87c442abf',
#  'https://vanex.io/opportunity/547daa72-3fde-49f4-91b8-bdcde643b021',
#  'https://vanex.io/opportunity/5710bd39-9759-4755-8725-76583d38971e',
#  'https://vanex.io/opportunity/746a9728-ff22-443f-8743-8c40815d0250',
#  'https://vanex.io/opportunity/c6364f81-b759-45ff-9ab2-16b7ed0d8586',
#  'https://vanex.io/opportunity/be08dbaa-84fa-49b7-ab62-27de52b16ee9',
#  'https://vanex.io/opportunity/59ebf1a5-ca30-4167-8ef3-d1756df035b8',
#  'https://vanex.io/opportunity/f00008a5-e1e8-48e1-8356-c450c68161db',
#  'https://vanex.io/opportunity/b2a1d5e6-c8fd-4e80-8730-123d7c359ff4',
#  'https://vanex.io/opportunity/38caa3f0-acf5-40b3-8a7e-e162a174fb48',
#  'https://vanex.io/opportunity/d24889d0-d0fb-406b-887c-3a9f2ac110c5',
#  'https://vanex.io/opportunity/390e4fca-1841-4736-81f1-67d50e9e2ade',
#  'https://vanex.resuelve.io/opportunity/cec644a6-78fd-4bc4-932d-5a0cc4ce42a6',
# ...

# %%
enlaces_df =pd.DataFrame(enlace)
enlaces_df.head(10)
# Out:
#                                                    0
# 0  https://vanex.io/opportunity/78e94e3a-9fa8-4f0...
# 1  https://vanex.io/opportunity/547daa72-3fde-49f...
# 2  https://vanex.io/opportunity/5710bd39-9759-475...
# 3  https://vanex.io/opportunity/746a9728-ff22-443...
# 4  https://vanex.io/opportunity/c6364f81-b759-45f...
# 5  https://vanex.io/opportunity/be08dbaa-84fa-49b...
# 6  https://vanex.io/opportunity/59ebf1a5-ca30-416...
# 7  https://vanex.io/opportunity/f00008a5-e1e8-48e...
# 8  https://vanex.io/opportunity/b2a1d5e6-c8fd-4e8...
# 9  https://vanex.io/opportunity/38caa3f0-acf5-40b...

# %%
nombres2=[]
calificacion2= []
i=0
for index, row in enlaces_df.iloc[1048:].iterrows():
#for e in pulpo_df['link']:
    i+=1
    driver.get(e)
    time.sleep(2)
    n= driver.find_element(By.XPATH, "//*[@class='main-title']").text
    cali= driver.find_element(By.XPATH, "//*[@class='status tag']").text
    nombres2.append(n)
    calificacion2.append(cali)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[145], line 9
#       7 driver.get(e)
#       8 time.sleep(2)
# ----> 9 n= driver.find_element(By.XPATH, "//*[@class='main-title']").text
#      10 cali= driver.find_element(By.XPATH, "//*[@class='status tag']").text
#      11 nombres2.append(n)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:740, in WebDriver.find_element(self, by, value)
#     737     by = By.CSS_SELECTOR
#     738     value = f'[name="{value}"]'
# --> 740 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
# ...
